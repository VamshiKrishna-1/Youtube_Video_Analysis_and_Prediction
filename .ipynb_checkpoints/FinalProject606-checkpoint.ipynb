# %% [markdown]
# ### Importing necessary libraries

# %%
# !pip install opendatasets
# Out:
# Requirement already satisfied: opendatasets in c:\programdata\anaconda3\lib\site-packages (0.1.22)
# Requirement already satisfied: tqdm in c:\programdata\anaconda3\lib\site-packages (from opendatasets) (4.62.3)
# Requirement already satisfied: click in c:\programdata\anaconda3\lib\site-packages (from opendatasets) (8.0.3)
# Requirement already satisfied: kaggle in c:\programdata\anaconda3\lib\site-packages (from opendatasets) (1.5.12)
# Requirement already satisfied: colorama in c:\programdata\anaconda3\lib\site-packages (from click->opendatasets) (0.4.4)
# Requirement already satisfied: urllib3 in c:\programdata\anaconda3\lib\site-packages (from kaggle->opendatasets) (1.26.7)
# Requirement already satisfied: python-dateutil in c:\programdata\anaconda3\lib\site-packages (from kaggle->opendatasets) (2.8.2)
# Requirement already satisfied: python-slugify in c:\programdata\anaconda3\lib\site-packages (from kaggle->opendatasets) (5.0.2)
# Requirement already satisfied: six>=1.10 in c:\programdata\anaconda3\lib\site-packages (from kaggle->opendatasets) (1.16.0)
# Requirement already satisfied: requests in c:\programdata\anaconda3\lib\site-packages (from kaggle->opendatasets) (2.26.0)
# Requirement already satisfied: certifi in c:\programdata\anaconda3\lib\site-packages (from kaggle->opendatasets) (2021.10.8)
# Requirement already satisfied: text-unidecode>=1.3 in c:\programdata\anaconda3\lib\site-packages (from python-slugify->kaggle->opendatasets) (1.3)
# Requirement already satisfied: idna<4,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests->kaggle->opendatasets) (3.2)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\programdata\anaconda3\lib\site-packages (from requests->kaggle->opendatasets) (2.0.4)
# WARNING: Ignoring invalid distribution -nyio (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -nyio (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -nyio (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -nyio (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -nyio (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -nyio (c:\programdata\anaconda3\lib\site-packages)

# %%
pip install --upgrade google-api-python-client
# Out:
# Requirement already satisfied: google-api-python-client in c:\programdata\anaconda3\lib\site-packages (2.80.0)
# Requirement already satisfied: google-auth<3.0.0dev,>=1.19.0 in c:\programdata\anaconda3\lib\site-packages (from google-api-python-client) (2.16.2)
# Requirement already satisfied: httplib2<1dev,>=0.15.0 in c:\programdata\anaconda3\lib\site-packages (from google-api-python-client) (0.21.0)
# Requirement already satisfied: google-auth-httplib2>=0.1.0 in c:\programdata\anaconda3\lib\site-packages (from google-api-python-client) (0.1.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in c:\programdata\anaconda3\lib\site-packages (from google-api-python-client) (4.1.1)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5 in c:\programdata\anaconda3\lib\site-packages (from google-api-python-client) (2.11.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.19.5 in c:\programdata\anaconda3\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client) (4.22.0)
# Requirement already satisfied: requests<3.0.0dev,>=2.18.0 in c:\programdata\anaconda3\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client) (2.26.0)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.56.2 in c:\programdata\anaconda3\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client) (1.58.0)
# Requirement already satisfied: six>=1.9.0 in c:\programdata\anaconda3\lib\site-packages (from google-auth<3.0.0dev,>=1.19.0->google-api-python-client) (1.16.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\programdata\anaconda3\lib\site-packages (from google-auth<3.0.0dev,>=1.19.0->google-api-python-client) (4.9)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\programdata\anaconda3\lib\site-packages (from google-auth<3.0.0dev,>=1.19.0->google-api-python-client) (5.3.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\programdata\anaconda3\lib\site-packages (from google-auth<3.0.0dev,>=1.19.0->google-api-python-client) (0.2.8)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in c:\programdata\anaconda3\lib\site-packages (from httplib2<1dev,>=0.15.0->google-api-python-client) (3.0.4)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\programdata\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0dev,>=1.19.0->google-api-python-client) (0.4.8)
# Requirement already satisfied: idna<4,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client) (3.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client) (1.26.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\programdata\anaconda3\lib\site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client) (2021.10.8)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -nyio (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -nyio (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -nyio (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -nyio (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -nyio (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -nyio (c:\programdata\anaconda3\lib\site-packages)

# %%
pip install --upgrade google-auth-oauthlib google-auth-httplib2
# Out:
# Requirement already satisfied: google-auth-oauthlib in c:\programdata\anaconda3\lib\site-packages (1.0.0)
# Requirement already satisfied: google-auth-httplib2 in c:\programdata\anaconda3\lib\site-packages (0.1.0)
# Requirement already satisfied: google-auth>=2.15.0 in c:\programdata\anaconda3\lib\site-packages (from google-auth-oauthlib) (2.16.2)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\programdata\anaconda3\lib\site-packages (from google-auth-oauthlib) (1.3.1)
# Requirement already satisfied: httplib2>=0.15.0 in c:\programdata\anaconda3\lib\site-packages (from google-auth-httplib2) (0.21.0)
# Requirement already satisfied: six in c:\programdata\anaconda3\lib\site-packages (from google-auth-httplib2) (1.16.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\programdata\anaconda3\lib\site-packages (from google-auth>=2.15.0->google-auth-oauthlib) (5.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\programdata\anaconda3\lib\site-packages (from google-auth>=2.15.0->google-auth-oauthlib) (4.9)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\programdata\anaconda3\lib\site-packages (from google-auth>=2.15.0->google-auth-oauthlib) (0.2.8)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in c:\programdata\anaconda3\lib\site-packages (from httplib2>=0.15.0->google-auth-httplib2) (3.0.4)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\programdata\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth>=2.15.0->google-auth-oauthlib) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\programdata\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib) (3.2.2)
# Requirement already satisfied: requests>=2.0.0 in c:\programdata\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib) (2.26.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib) (3.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib) (1.26.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\programdata\anaconda3\lib\site-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib) (2.0.4)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -nyio (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -nyio (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -nyio (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -nyio (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -nyio (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -nyio (c:\programdata\anaconda3\lib\site-packages)

# %%
import opendatasets as od
import os
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import json
import warnings
import numpy as np
import statistics as st
import plotly.express as px
import google_auth_oauthlib.flow
import googleapiclient.discovery
import googleapiclient.errors
from IPython.display import JSON
#import isodate


warnings.filterwarnings('ignore')

# %% [markdown]
# ### Loading the dataset from the source

# %%
dataset = 'https://www.kaggle.com/datasets/rsrishav/youtube-trending-video-dataset?select=US_youtube_trending_data.csv'

final_dir = '\\'.join(os.getcwd().split('\\')[:-1])

# %%
od.download(dataset, data_dir=final_dir)

final_dir += '\\youtube-trending-video-dataset\\US_youtube_trending_data.csv'
# Out:
# Skipping, found downloaded files in "C:\Users\pooja\OneDrive\Desktop\Semester 3\Data 606 Capstone in DataScience\youtube-trending-video-dataset" (use force=True to force download)

# %%
data = pd.read_csv(final_dir)

data.head(3)
# Out:
#       video_id                                              title  \
# 0  3C66w5Z0ixs                 I ASKED HER TO BE MY GIRLFRIEND...
# 1  M9Pmf9AB4Mo  Apex Legends | Stories from the Outlands – “Th...
# 2  J78aPJ3VyNs  I left youtube for a month and THIS is what ha...
#
#             publishedAt                 channelId   channelTitle  categoryId  \
# 0  2020-08-11T19:20:14Z  UCvtRTOMP2TqYqu51xNrqAzg       Brawadis          22
# 1  2020-08-11T17:00:10Z  UC0ZV6M2THA81QT9hrVWJG3A   Apex Legends          20
# 2  2020-08-11T16:34:06Z  UCYzPXprvl5Y-Sf0g4vX-m6g  jacksepticeye          24
#
#           trending_date                                               tags  \
# 0  2020-08-12T00:00:00Z  brawadis|prank|basketball|skits|ghost|funny vi...
# 1  2020-08-12T00:00:00Z  Apex Legends|Apex Legends characters|new Apex ...
# 2  2020-08-12T00:00:00Z  jacksepticeye|funny|funny meme|memes|jacksepti...
#
#    view_count   likes  dislikes  comment_count  \
# 0     1514614  156908      5855          35313
# 1     2381688  146739      2794          16549
# 2     2038853  353787      2628          40221
#
#                                    thumbnail_link  comments_disabled  \
# 0  https://i.ytimg.com/vi/3C66w5Z0ixs/default.jpg              False
# 1  https://i.ytimg.com/vi/M9Pmf9AB4Mo/default.jpg              False
# 2  https://i.ytimg.com/vi/J78aPJ3VyNs/default.jpg              False
#
#    ratings_disabled                                        description
# 0             False  SUBSCRIBE to BRAWADIS ▶ http://bit.ly/Subscrib...
# 1             False  While running her own modding shop, Ramya Pare...
# 2             False  I left youtube for a month and this is what ha...

# %% [markdown]
# ### Understanding the data

# %%
# Checking the shape of the DataFrame
data.shape
# Out:
# (187790, 16)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 187790 entries, 0 to 187789
# Data columns (total 16 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   video_id           187790 non-null  object
#  1   title              187790 non-null  object
#  2   publishedAt        187790 non-null  object
#  3   channelId          187790 non-null  object
#  4   channelTitle       187790 non-null  object
#  5   categoryId         187790 non-null  int64
#  6   trending_date      187790 non-null  object
#  7   tags               187790 non-null  object
#  8   view_count         187790 non-null  int64
#  9   likes              187790 non-null  int64
#  10  dislikes           187790 non-null  int64
#  11  comment_count      187790 non-null  int64
#  12  thumbnail_link     187790 non-null  object
#  13  comments_disabled  187790 non-null  bool
#  14  ratings_disabled   187790 non-null  bool
#  15  description        183729 non-null  object
# dtypes: bool(2), int64(5), object(9)
# memory usage: 20.4+ MB

# %%
# Checking null values

def null_values(df):
    temp = df.isna().sum()
    temp_1 = round(temp * 100 / df.shape[0], 2)
    
    return pd.DataFrame((temp, temp_1), index = ['Count', 'Percentage']).T.sort_values('Count', ascending = False)


null_df = null_values(data).reset_index().rename({'index':'Column_name'}, axis =1)
null_df
# Out:
#           Column_name   Count  Percentage
# 0         description  4061.0        2.16
# 1            video_id     0.0        0.00
# 2               title     0.0        0.00
# 3         publishedAt     0.0        0.00
# 4           channelId     0.0        0.00
# 5        channelTitle     0.0        0.00
# 6          categoryId     0.0        0.00
# 7       trending_date     0.0        0.00
# 8                tags     0.0        0.00
# 9          view_count     0.0        0.00
# 10              likes     0.0        0.00
# 11           dislikes     0.0        0.00
# 12      comment_count     0.0        0.00
# 13     thumbnail_link     0.0        0.00
# 14  comments_disabled     0.0        0.00
# 15   ratings_disabled     0.0        0.00

# %% [markdown]
# We can see that there are around 10% missing values in `description` column
# - We are keeping the `description` column as it is while analysis and perform the null value treatment during model building.

# %% [markdown]
# - We also observed that the data has certain important columns missing in it. Such as `VideoDuration` and `Comments` of video which are very useful for further analysis.
# - We used `video_id` to extract the data from `YOUTUBE API`.
# - The link for the Youtube API is: https://developers.google.com/youtube/v3/quickstart/python
#
# - While trying to extract the data we found that the video IDs are repeating which are causing duplicate rows in the dataset.
# - There are only 34066 unique videos out of 185990 video ids.
# #### Reason:
# - The videos are repeating as they are trending for multiple number of days.
# - The combination of `video_id` and `trending_date` gives us the information about how many days a specific video have been trending.
# - Let's consider an example below

# %%
# Let's check the unique video_ids in the `video_id` column
data['video_id'].nunique()
# Out:
# 34391

# %%
# This code shows an example of how a randomly chosen video_id has continuous trending_dates
example_id = data['video_id'].value_counts().sort_values(ascending = False).index[np.random.randint(10,20)]

df=data[data['video_id'] == example_id]
df
# Out:
#           video_id                                       title  \
# 7401   pvPsJFRGleA  Justin Bieber - Holy ft. Chance The Rapper
# 7602   pvPsJFRGleA  Justin Bieber - Holy ft. Chance The Rapper
# 7806   pvPsJFRGleA  Justin Bieber - Holy ft. Chance The Rapper
# 8273   pvPsJFRGleA  Justin Bieber - Holy ft. Chance The Rapper
# 8722   pvPsJFRGleA  Justin Bieber - Holy ft. Chance The Rapper
# 8949   pvPsJFRGleA  Justin Bieber - Holy ft. Chance The Rapper
# 9132   pvPsJFRGleA  Justin Bieber - Holy ft. Chance The Rapper
# 9335   pvPsJFRGleA  Justin Bieber - Holy ft. Chance The Rapper
# 9528   pvPsJFRGleA  Justin Bieber - Holy ft. Chance The Rapper
# 9745   pvPsJFRGleA  Justin Bieber - Holy ft. Chance The Rapper
# 9965   pvPsJFRGleA  Justin Bieber - Holy ft. Chance The Rapper
# 10157  pvPsJFRGleA  Justin Bieber - Holy ft. Chance The Rapper
# 10339  pvPsJFRGleA  Justin Bieber - Holy ft. Chance The Rapper
# 10519  pvPsJFRGleA  Justin Bieber - Holy ft. Chance The Rapper
# 10731  pvPsJFRGleA  Justin Bieber - Holy ft. Chance The Rapper
# 10985  pvPsJFRGleA  Justin Bieber - Holy ft. Chance The Rapper
# 11191  pvPsJFRGleA  Justin Bieber - Holy ft. Chance The Rapper
# 11388  pvPsJFRGleA  Justin Bieber - Holy ft. Chance The Rapper
# 11577  pvPsJFRGleA  Justin Bieber - Holy ft. Chance The Rapper
# 11761  pvPsJFRGleA  Justin Bieber - Holy ft. Chance The Rapper
# 11958  pvPsJFRGleA  Justin Bieber - Holy ft. Chance The Rapper
# 12158  pvPsJFRGleA  Justin Bieber - Holy ft. Chance The Rapper
# 12380  pvPsJFRGleA  Justin Bieber - Holy ft. Chance The Rapper
# 12574  pvPsJFRGleA  Justin Bieber - Holy ft. Chance The Rapper
# 12787  pvPsJFRGleA  Justin Bieber - Holy ft. Chance The Rapper
# 13390  pvPsJFRGleA  Justin Bieber - Holy ft. Chance The Rapper
# 13587  pvPsJFRGleA  Justin Bieber - Holy ft. Chance The Rapper
#
#                 publishedAt                 channelId      channelTitle  \
# 7401   2020-09-18T04:00:10Z  UCHkj014U2CQ2Nv0UZeYpE_A  JustinBieberVEVO
# 7602   2020-09-18T04:00:10Z  UCHkj014U2CQ2Nv0UZeYpE_A  JustinBieberVEVO
# 7806   2020-09-18T04:00:10Z  UCHkj014U2CQ2Nv0UZeYpE_A  JustinBieberVEVO
# 8273   2020-09-18T04:00:10Z  UCHkj014U2CQ2Nv0UZeYpE_A  JustinBieberVEVO
# 8722   2020-09-18T04:00:10Z  UCHkj014U2CQ2Nv0UZeYpE_A  JustinBieberVEVO
# 8949   2020-09-18T04:00:10Z  UCHkj014U2CQ2Nv0UZeYpE_A  JustinBieberVEVO
# 9132   2020-09-18T04:00:10Z  UCHkj014U2CQ2Nv0UZeYpE_A  JustinBieberVEVO
# 9335   2020-09-18T04:00:10Z  UCHkj014U2CQ2Nv0UZeYpE_A  JustinBieberVEVO
# 9528   2020-09-18T04:00:10Z  UCHkj014U2CQ2Nv0UZeYpE_A  JustinBieberVEVO
# 9745   2020-09-18T04:00:10Z  UCHkj014U2CQ2Nv0UZeYpE_A  JustinBieberVEVO
# 9965   2020-09-18T04:00:10Z  UCHkj014U2CQ2Nv0UZeYpE_A  JustinBieberVEVO
# 10157  2020-09-18T04:00:10Z  UCHkj014U2CQ2Nv0UZeYpE_A  JustinBieberVEVO
# 10339  2020-09-18T04:00:10Z  UCHkj014U2CQ2Nv0UZeYpE_A  JustinBieberVEVO
# 10519  2020-09-18T04:00:10Z  UCHkj014U2CQ2Nv0UZeYpE_A  JustinBieberVEVO
# 10731  2020-09-18T04:00:10Z  UCHkj014U2CQ2Nv0UZeYpE_A  JustinBieberVEVO
# 10985  2020-09-18T04:00:10Z  UCHkj014U2CQ2Nv0UZeYpE_A  JustinBieberVEVO
# 11191  2020-09-18T04:00:10Z  UCHkj014U2CQ2Nv0UZeYpE_A  JustinBieberVEVO
# 11388  2020-09-18T04:00:10Z  UCHkj014U2CQ2Nv0UZeYpE_A  JustinBieberVEVO
# 11577  2020-09-18T04:00:10Z  UCHkj014U2CQ2Nv0UZeYpE_A  JustinBieberVEVO
# 11761  2020-09-18T04:00:10Z  UCHkj014U2CQ2Nv0UZeYpE_A  JustinBieberVEVO
# 11958  2020-09-18T04:00:10Z  UCHkj014U2CQ2Nv0UZeYpE_A  JustinBieberVEVO
# 12158  2020-09-18T04:00:10Z  UCHkj014U2CQ2Nv0UZeYpE_A  JustinBieberVEVO
# 12380  2020-09-18T04:00:10Z  UCHkj014U2CQ2Nv0UZeYpE_A  JustinBieberVEVO
# 12574  2020-09-18T04:00:10Z  UCHkj014U2CQ2Nv0UZeYpE_A  JustinBieberVEVO
# 12787  2020-09-18T04:00:10Z  UCHkj014U2CQ2Nv0UZeYpE_A  JustinBieberVEVO
# 13390  2020-09-18T04:00:10Z  UCHkj014U2CQ2Nv0UZeYpE_A  JustinBieberVEVO
# 13587  2020-09-18T04:00:10Z  UCHkj014U2CQ2Nv0UZeYpE_A  JustinBieberVEVO
#
#        categoryId         trending_date  \
# 7401           10  2020-09-18T00:00:00Z
# 7602           10  2020-09-19T00:00:00Z
# 7806           10  2020-09-20T00:00:00Z
# 8273           10  2020-09-22T00:00:00Z
# 8722           10  2020-09-24T00:00:00Z
# 8949           10  2020-09-25T00:00:00Z
# 9132           10  2020-09-26T00:00:00Z
# 9335           10  2020-09-27T00:00:00Z
# 9528           10  2020-09-28T00:00:00Z
# 9745           10  2020-09-29T00:00:00Z
# 9965           10  2020-09-30T00:00:00Z
# 10157          10  2020-10-01T00:00:00Z
# 10339          10  2020-10-02T00:00:00Z
# 10519          10  2020-10-03T00:00:00Z
# 10731          10  2020-10-04T00:00:00Z
# 10985          10  2020-10-05T00:00:00Z
# 11191          10  2020-10-06T00:00:00Z
# 11388          10  2020-10-07T00:00:00Z
# 11577          10  2020-10-08T00:00:00Z
# 11761          10  2020-10-09T00:00:00Z
# 11958          10  2020-10-10T00:00:00Z
# 12158          10  2020-10-11T00:00:00Z
# 12380          10  2020-10-12T00:00:00Z
# 12574          10  2020-10-13T00:00:00Z
# 12787          10  2020-10-14T00:00:00Z
# 13390          10  2020-10-17T00:00:00Z
# 13587          10  2020-10-18T00:00:00Z
#
#                                                     tags  view_count    likes  \
# 7401                 Justin|Bieber|Holy|RBMG/Def|Jam|Pop     6217404   936304
# 7602   justin bieber|bieber|justin|hailey|biebs|biebe...    16239716  1555576
# 7806   justin bieber|bieber|justin|hailey|biebs|biebe...    22349477  1851026
# 8273   justin bieber|bieber|justin|hailey|biebs|biebe...    28381347  2077535
# 8722   justin bieber|bieber|justin|hailey|biebs|biebe...    32772710  2229874
# 8949   justin bieber|bieber|justin|hailey|biebs|biebe...    34763995  2288738
# 9132   justin bieber|bieber|justin|hailey|biebs|biebe...    36350151  2331823
# 9335   justin bieber|bieber|justin|hailey|biebs|biebe...    37731225  2364416
# 9528   justin bieber|bieber|justin|hailey|biebs|biebe...    38942701  2391684
# 9745   justin bieber|bieber|justin|hailey|biebs|biebe...    40157565  2419281
# 9965   justin bieber|bieber|justin|hailey|biebs|biebe...    41347429  2443737
# 10157  justin bieber|bieber|justin|hailey|biebs|biebe...    42443791  2464848
# 10339  justin bieber|bieber|justin|hailey|biebs|biebe...    43537279  2486859
# 10519  justin bieber|bieber|justin|hailey|biebs|biebe...    44708896  2508294
# 10731  justin bieber|bieber|justin|hailey|biebs|biebe...    45712761  2526635
# 10985  justin bieber|bieber|justin|hailey|biebs|biebe...    46502079  2542449
# 11191  justin bieber|bieber|justin|hailey|biebs|biebe...    47293715  2557328
# 11388  justin bieber|bieber|justin|hailey|biebs|biebe...    48114098  2572626
# 11577  justin bieber|bieber|justin|hailey|biebs|biebe...    48943776  2588599
# 11761  justin bieber|bieber|justin|hailey|biebs|biebe...    49814886  2603781
# 11958  justin bieber|bieber|justin|hailey|biebs|biebe...    50755599  2619769
# 12158  justin bieber|bieber|justin|hailey|biebs|biebe...    51657385  2634098
# 12380  justin bieber|bieber|justin|hailey|biebs|biebe...    52474754  2647022
# 12574  justin bieber|bieber|justin|hailey|biebs|biebe...    53293397  2660160
# 12787  justin bieber|bieber|justin|hailey|biebs|biebe...    54082051  2672339
# 13390  justin bieber|bieber|justin|hailey|biebs|biebe...    56620947  2716375
# 13587  justin bieber|bieber|justin|hailey|biebs|biebe...    57463872  2731390
#
#        dislikes  comment_count  \
# 7401      13331          91366
# 7602      29634         134954
# 7806      39955         149395
# 8273      48096         162536
# 8722      53151         170185
# 8949      55087         173256
# 9132      56544         175811
# 9335      57780         177132
# 9528      58762         179139
# 9745      60017         180869
# 9965      60793         182376
# 10157     61514         183663
# 10339     62216         184916
# 10519     62860         185804
# 10731     63431         186490
# 10985     63891         187273
# 11191     64418         187921
# 11388     64802         188593
# 11577     65316         189303
# 11761     65855         190132
# 11958     66550         190418
# 12158     67254         191014
# 12380     68201         191573
# 12574     69107         192006
# 12787     69931         192612
# 13390     71669         194009
# 13587     71939         194456
#
#                                        thumbnail_link  comments_disabled  \
# 7401   https://i.ytimg.com/vi/pvPsJFRGleA/default.jpg              False
# 7602   https://i.ytimg.com/vi/pvPsJFRGleA/default.jpg              False
# 7806   https://i.ytimg.com/vi/pvPsJFRGleA/default.jpg              False
# 8273   https://i.ytimg.com/vi/pvPsJFRGleA/default.jpg              False
# 8722   https://i.ytimg.com/vi/pvPsJFRGleA/default.jpg              False
# 8949   https://i.ytimg.com/vi/pvPsJFRGleA/default.jpg              False
# 9132   https://i.ytimg.com/vi/pvPsJFRGleA/default.jpg              False
# 9335   https://i.ytimg.com/vi/pvPsJFRGleA/default.jpg              False
# 9528   https://i.ytimg.com/vi/pvPsJFRGleA/default.jpg              False
# 9745   https://i.ytimg.com/vi/pvPsJFRGleA/default.jpg              False
# 9965   https://i.ytimg.com/vi/pvPsJFRGleA/default.jpg              False
# 10157  https://i.ytimg.com/vi/pvPsJFRGleA/default.jpg              False
# 10339  https://i.ytimg.com/vi/pvPsJFRGleA/default.jpg              False
# 10519  https://i.ytimg.com/vi/pvPsJFRGleA/default.jpg              False
# 10731  https://i.ytimg.com/vi/pvPsJFRGleA/default.jpg              False
# 10985  https://i.ytimg.com/vi/pvPsJFRGleA/default.jpg              False
# 11191  https://i.ytimg.com/vi/pvPsJFRGleA/default.jpg              False
# 11388  https://i.ytimg.com/vi/pvPsJFRGleA/default.jpg              False
# 11577  https://i.ytimg.com/vi/pvPsJFRGleA/default.jpg              False
# 11761  https://i.ytimg.com/vi/pvPsJFRGleA/default.jpg              False
# 11958  https://i.ytimg.com/vi/pvPsJFRGleA/default.jpg              False
# 12158  https://i.ytimg.com/vi/pvPsJFRGleA/default.jpg              False
# 12380  https://i.ytimg.com/vi/pvPsJFRGleA/default.jpg              False
# 12574  https://i.ytimg.com/vi/pvPsJFRGleA/default.jpg              False
# 12787  https://i.ytimg.com/vi/pvPsJFRGleA/default.jpg              False
# 13390  https://i.ytimg.com/vi/pvPsJFRGleA/default.jpg              False
# 13587  https://i.ytimg.com/vi/pvPsJFRGleA/default.jpg              False
#
#        ratings_disabled                                        description
# 7401              False  Holy out now: https://JustinBieber.lnk.to/Holy...
# 7602              False  Holy out now: https://JustinBieber.lnk.to/Holy...
# 7806              False  Holy out now: https://JustinBieber.lnk.to/Holy...
# 8273              False  Holy out now: https://JustinBieber.lnk.to/Holy...
# 8722              False  Holy out now: https://JustinBieber.lnk.to/Holy...
# 8949              False  Holy out now: https://JustinBieber.lnk.to/Holy...
# 9132              False  Holy out now: https://JustinBieber.lnk.to/Holy...
# 9335              False  Holy out now: https://JustinBieber.lnk.to/Holy...
# 9528              False  Holy out now: https://JustinBieber.lnk.to/Holy...
# 9745              False  Holy out now: https://JustinBieber.lnk.to/Holy...
# 9965              False  Holy out now: https://JustinBieber.lnk.to/Holy...
# 10157             False  Holy out now: https://JustinBieber.lnk.to/Holy...
# 10339             False  Holy out now: https://JustinBieber.lnk.to/Holy...
# 10519             False  Holy out now: https://JustinBieber.lnk.to/Holy...
# 10731             False  Holy out now: https://JustinBieber.lnk.to/Holy...
# 10985             False  Holy out now: https://JustinBieber.lnk.to/Holy...
# 11191             False  Holy out now: https://JustinBieber.lnk.to/Holy...
# 11388             False  Holy out now: https://JustinBieber.lnk.to/Holy...
# 11577             False  Holy out now: https://JustinBieber.lnk.to/Holy...
# 11761             False  Holy out now: https://JustinBieber.lnk.to/Holy...
# 11958             False  Holy out now: https://JustinBieber.lnk.to/Holy...
# 12158             False  Holy out now: https://JustinBieber.lnk.to/Holy...
# 12380             False  Holy out now: https://JustinBieber.lnk.to/Holy...
# 12574             False  Holy out now: https://JustinBieber.lnk.to/Holy...
# 12787             False  Holy out now: https://JustinBieber.lnk.to/Holy...
# 13390             False  Holy out now: https://JustinBieber.lnk.to/Holy...
# 13587             False  Holy out now: https://JustinBieber.lnk.to/Holy...

# %% [markdown]
# - In the above example we can see that a specific video has been trending for days.
# - That means we have to modify the data such that it only has unique video_id in `video_id` column.

# %% [markdown]
# ### Extracting `Duration` and `Comments` from Youtube API

# %%
# First let's get unique video ids from the video_id column in dataframe

videos_list = data['video_id'].unique()

# %%
# The API_KEY is not displayed for security purposes

api_key = "*********************************"

# %%
# This fuction is used to extract 'Duration' and 'Comments' of a provided video_id

def get_video_info(vid_id, api_key):
    api_service_name = "youtube"
    api_version = "v3"

    youtube = googleapiclient.discovery.build(
        api_service_name, api_version, developerKey=api_key)

    request = youtube.videos().list(
        part="snippet,contentDetails,statistics,status",
        id=vid_id
    )
    
    response = request.execute()
    
    info_temp = []
    info_temp.append(vid_id)
    info_temp.append(response['items'][0]['contentDetails']['duration'])
    info_temp.append(response['items'][0]['status']['madeForKids'])
    
    youtube = googleapiclient.discovery.build(
    api_service_name, api_version, developerKey = api_key)

    request = youtube.commentThreads().list(
        part="snippet,replies",
        videoId=vid_id,
        textFormat = "plainText",
        order = "relevance"
    )
    response_comments = request.execute()
    
    info_temp.append([response_comments['items'][i]['snippet']['topLevelComment']['snippet']['textOriginal'] for i in range(20)])
    
    
    return info_temp



# This function is used to create a dataframe from the list of video_ids in video_list and save it in the repository.
# Start and end number is the range of video_ids you want the data for.

def data_to_csv(videos_list, start_number, end_number):
    print("Code Running")
    video_info = []
    deleted_videos = []
    
    for vid_id in videos_list[start_number : end_number]:
        try:
            video_info.append(get_video_info(vid_id, api_key))
        except:
            deleted_videos.append(vid_id)
    
    print("Number of videos extracted =", len(video_info))
    print("Number of video deleted =", len(deleted_videos))
    
    df = pd.DataFrame(video_info, columns = ['video_id', 'Duration', 'madeForKids', 'Comments'])
    df.to_csv('./YoutubeDataFiles/Data_' + str(start_number) + '_' + str(end_number) + '.csv')
    
    
# Saving the data to a .csv file by calling the funciton

#data_to_csv(videos_list, 0, 5000)

# %% [markdown]
# - Although it was possible to extract all the video_ids at once. It would cost money if you were to extract more than 5000.
# - Hence, we used different API_KEYS and various start & end_numbers to save the files in the repository.
# - The files are stored in `./YoutubeDataFiles` directory.
# - The .csv files follow the convention `Data_startnumber_endnumber.csv`.

# %%
# Let's read the 'extracted files' in and merge them to merge with original Dataframe

# extracted_df =

# %% [markdown]
# ### Modifying the Original Dataframe

# %%
# Checking column name and values in the dataframe

data.head(1)
# Out:
#       video_id                               title           publishedAt  \
# 0  3C66w5Z0ixs  I ASKED HER TO BE MY GIRLFRIEND...  2020-08-11T19:20:14Z
#
#                   channelId channelTitle  categoryId         trending_date  \
# 0  UCvtRTOMP2TqYqu51xNrqAzg     Brawadis          22  2020-08-12T00:00:00Z
#
#                                                 tags  view_count   likes  \
# 0  brawadis|prank|basketball|skits|ghost|funny vi...     1514614  156908
#
#    dislikes  comment_count                                  thumbnail_link  \
# 0      5855          35313  https://i.ytimg.com/vi/3C66w5Z0ixs/default.jpg
#
#    comments_disabled  ratings_disabled  \
# 0              False             False
#
#                                          description
# 0  SUBSCRIBE to BRAWADIS ▶ http://bit.ly/Subscrib...

# %%
# Checking the datatypes of each column

data.dtypes

# %% [markdown]
# Let's make the following changes to the Original Dataframe in 4 major steps:
#
# 1. Drop `channelId` column as it is not necessary for the analysis and prediction.
# <br>
#
# 2. Convert `publishedAt` and `trending_date` to Pandas_Datetime object. Map each category_id to respective category in `categroty_id` column. This is done using `US_category_id.json` file from the source file.
# <br>
#
# 3. Groupby `video_id` column and apply the following functions to the rest of the columns:
# - `title` - <b>Function : MODE</b> - because title is same for each video_id.
# - `publishedAT` - <b>Function : MODE</b> - although published date is same for each video_id. Let's consider minimum value.
# - `channelTitle` - <b>Function : MODE</b> - because channel title is same for each video_id.
# - `categroryId` - <b>Function : MODE</b> - because categoryId is same for each video_id.
# - `trending_date` - <b>Function : [min(trending_date), max(trending_date)]</b> - this is because we can extract features like `How many days video took to get into trending list` and `How many days the video havee been trending`.
# - `tags` - <b>Function : MODE</b> - because tags are same for each video_id.
# - `likes` - <b>Function : [min(likes), max(likes)]</b> - this is because we can extract features like `How many likes have been increased during the period`.
# - `comments_disabled` - <b>Function : MODE</b> - because comments_disabled_flag is same for each video_id.
# - `ratings_disabled` - <b>Function : MODE</b> - because ratings_disabled_flag is same for each video_id.
# <br>
# <br>
#
# 4. Drop `dislikes` column as the dislikes has been discontinued from November 2021.
# Reference: https://www.google.com/search?q=when+did+youtube+remove+dislikes&rlz=1C1UEAD_enUS1037US1037&oq=when+did+youtube+remove+&aqs=chrome.0.0i512j69i57j0i512l6j0i22i30l2.6954j1j4&sourceid=chrome&ie=UTF-8

# %% [markdown]
# #### Step - 1

# %%
# Dropping channelId

data.drop(['channelId'], axis = 1, inplace = True)

# Validating the above code

data.head(3)

# %% [markdown]
# #### Step - 2

# %% [markdown]
# - `publishedAt`, `trending_date` are object type. Let's convert it to Datetime format.

# %%
# Converting 'publishedAt' and 'trending_date' to datetime objects

data[['publishedAt', 'trending_date']] = data[['publishedAt', 'trending_date']].apply(lambda x: pd.to_datetime(x))

# Validating the above changes

data.dtypes[['publishedAt', 'trending_date']]

# %% [markdown]
# We can see that `categoryId` column has id's of repective categories. We can access the description of categoryId from the `US_category_id.json` file.

# %%
# Let's import US_category_id.json file and map the category id's respectively

category_path = '\\'.join(final_dir.split('\\')[:-1]) + '\\US_category_id.json'


# Creating a dictionary object which stores the category id and its respective category
category_dict = {}

with open(category_path, 'r') as file:
    json_data = json.load(file)
    for item in json_data['items']:
        category_dict[int(item['id'])] = item['snippet']['title']
    
data['categoryId'] = data['categoryId'].apply(lambda x: category_dict[x])

# Validating the above code
data['categoryId'].head()

# %% [markdown]
# #### Step - 3 and 4

# %%
# This function converts list to min_max_list as per conditions specified in the above cell

def column_start_end(x: list) -> list:
    return([min(x), max(x)])


# Grouping by 'video_id' and aggregating using functions as specified in the above cell

modified_df = data.groupby('video_id').agg({'title':st.mode, 'publishedAt':np.min, 'channelTitle':st.mode, 'categoryId':st.mode,
              'trending_date': column_start_end, 'tags': st.mode, 'likes': column_start_end,
                'comments_disabled': st.mode, 'ratings_disabled': st.mode}).reset_index()

modified_df.head(2)

# %%
modified_df.shape

# %% [markdown]
# The resulting dataframe has 34066 rows and 10 columns.
#
# Let's make the following changes to the resulting dataframe in 7 steps:
# 1. Create new columns `trending_date_start` & `trending_date_end` from `trending_date` column.
# 2. Create new columns `likes_start` & `likes_end` from `likes` column.
# 3. `tags` have `[None]` values in it. Converting them to Null values.
# 4. Create new column `tagsCount` from `tags` column. Which indicates the number of tags used in particular video.
# 5. Create new column `hoursTakenToTrend` from `trending_date_start` & `publishedAt` columns.
# 6. Create new column `trendingDaysDuration` from `trending_date_end` & `trending_date_start` columns.
# 7. Drop columns `trending_date`, `likes`, `publishedAt` as they are no longer required.

# %% [markdown]
# #### Step - 1

# %%
# Create new columns trending_date_start & trending_date_end from trending_date column.

modified_df['trending_date_start'] = modified_df['trending_date'].apply(lambda x: min(x))
modified_df['trending_date_end'] = modified_df['trending_date'].apply(lambda x: max(x))

# %% [markdown]
# #### Step - 2

# %%
# Create new columns likes_start & likes_end from likes column.

modified_df['likes_start'] = modified_df['likes'].apply(lambda x: min(x))
modified_df['likes_end'] = modified_df['likes'].apply(lambda x: max(x))
# df.drop('likes', axis = 1, inplace = True)

# %% [markdown]
# #### Step - 3

# %%
# tags have [None] values in it. Converting them to Null values.

modified_df['tags'] = modified_df['tags'].apply(lambda x: x if x!= '[None]' else np.nan)

# %% [markdown]
# #### Step - 4

# %%
# Create new column tagsCount from tags column. Which indicates the number of tags used in particular video.

modified_df['tagCount'] = modified_df['tags'].apply(lambda x: 0 if type(x) == float else len(list(x.split('|'))))

# %% [markdown]
# #### Step - 5

# %%
# Create new column hoursTakenToTrend from trending_date_start & publishedAt columns.

modified_df['hoursTakenToTrend'] = round((modified_df['trending_date_start'] - modified_df['publishedAt']).dt.seconds/(60*60), 1)

# %% [markdown]
# #### Step - 6

# %%
# Create new column trendingDaysDuration from trending_date_end & trending_date_start columns.

modified_df['trendingDaysDuration'] = (modified_df['trending_date_end'] - modified_df['trending_date_start']).dt.days

# %% [markdown]
# #### Step - 7

# %%
# Drop columns trending_date, likes, publishedAt as they are no longer required.

modified_df.drop(['trending_date', 'likes', 'publishedAt'], axis = 1, inplace = True)

# %%
# Displaying the dataframe after all the changes

modified_df.head(3)

# %%
# Displaying shape of Dataframe after all the changes

modified_df.shape

# %%
# Displaying the datatypes of the resultant Dataframe

modified_df.dtypes

# %% [markdown]
# ### Let's merge `modified_df` and `extracted_df`

# %%
#final_df = pd.merge((modified_df, extracted_df), on = 'video_id', how = 'inner')

# %%
# Displaying shape of final dataframe

#final_df.shape

# %%
# Displaying final dataframe

#final_df.head()

# %% [markdown]
# `Duration` column is in ISO Date format. Let's convert it into seconds

# %%
# Converting time in 'Duration' column to Seconds

#final_df['Duration'] = final_df['Duration'].apply(lambda x: isodate.parse_duration(x).total_seconds())

# Validating the above changes

#final_df.head(2)

# %% [markdown]
# ## Exploratory Data Analysis

# %%
# Let's check the correlation between the numerical columns

plt.figure(figsize = (10, 8))
sns.heatmap(data[['view_count', 'likes', 'dislikes', 'comment_count', 'daysTakenToTrend', 'tagCount']].corr(), linewidths=.5, annot=True, cmap='coolwarm')
plt.show()

# %% [markdown]
# - `view_count` and `likes` are highly correlated. It is more likely that the video with more views has more likes.
# - `comment_count` and `likes` are relatively highly correlated when compared to `comment_count` and `views`.
# - `daysTakenToTrend` is not correlated to any feature. Which is interesting as it is impossible to correlate how many days the video will take to trend based on comment_count or dislikes or likes or view_count.

# %%
######################### likes per view

# %%
# Checking number of videos based on each Category

plt.figure(figsize = (10, 4))
sns.countplot(data['categoryId'], order = data['categoryId'].value_counts().sort_values(ascending = False).index)
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# There are more `Entertainment` videos and least type is `Nonprofits & Activism`

# %%
plt.figure(figsize = (10, 6))
sns.barplot(data = data, x = 'categoryId', y = 'likes',
            order = data.groupby('categoryId')['likes'].mean().sort_values(ascending = False).index, ci = 0)

plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# - `Pets & Animals` videos has most average likes and `New & Policts` videos has least average likes.

# %%
plt.figure(figsize = (10, 6))
sns.barplot(data = data, x = 'categoryId', y = 'comment_count',
            order = data.groupby('categoryId')['comment_count'].mean().sort_values(ascending = False).index, ci = 0)

plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# `Music` videos has most average comment count and `Nonprofits & Activism` has least average comment count.

# %%
plt.figure(figsize = (10, 6))
sns.barplot(data = data, x = 'categoryId', y = 'daysTakenToTrend',
            order = data.groupby('categoryId')['daysTakenToTrend'].mean().sort_values(ascending = False).index, ci = 0)

plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# It is interesting to note that `News & Politics` videos take less time to trend and `Music`, `Comedy` and `Pets & Animals` videos take more time to trend.

# %%
sns.countplot(data['comments_disabled'])
plt.show()

# %%
plt.figure(figsize = (10, 5))
sns.countplot(data[data['ratings_disabled'] == True]['categoryId'], 
              order = data[data['ratings_disabled'] == True].groupby('categoryId')['ratings_disabled'].count().sort_values(ascending = False).index)
plt.xticks(rotation = 90)
plt.show()

# %%
plt.figure(figsize = (10, 5))
sns.countplot(data[data['tags'] == '[None]']['categoryId'], 
              order = data[data['tags'] == '[None]'].groupby('categoryId')['ratings_disabled'].count().sort_values(ascending = False).index)
plt.xticks(rotation = 90)
plt.show()

# %%
# Let's extract weekday from the trendingdate
data['day'] = data['trending_date'].dt.day_name()

# %%
# Let's plot number of trending videos for each day of the week
sns.countplot(data['day'])
plt.show()

# %%
# Daily several videos trend but which video trends for the longest number of days will be the question.

# %%
# Modify
plt.figure(figsize = (15,4))
sns.countplot(data = data, x = 'categoryId', hue = 'day')

# %%
# categories that are taking minimum or moderate or maximum number of days to trend
(data.groupby('categoryId')['daysTakenToTrend'].var().sort_values()).plot.bar()

# %%
data['like/dislike ratio'] = round(data['likes']/data['dislikes'], 2)

# %%
# Modify
plt.figure(figsize = (8, 10))
sns.histplot(data = data, x = 'like/dislike ratio', y = 'categoryId')
